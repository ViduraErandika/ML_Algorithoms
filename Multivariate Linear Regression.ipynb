# %%
import numpy as np
import pandas as pd
import random
import seaborn as sns

from sklearn.model_selection import train_test_split

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %%
df_data = pd.read_csv('C:/Users/vidur/Downloads/housing/House_Price.csv', encoding='utf-8')
df_data.head()
# Out:
#            id   Date  bedrooms  number of bathrooms  living_area  lot area  \
# 0  6762810145  42491         5                 2.50         3650      9050
# 1  6762810635  42491         4                 2.50         2920      4000
# 2  6762810998  42491         5                 2.75         2910      9480
# 3  6762812605  42491         4                 2.50         3310     42998
# 4  6762812919  42491         3                 2.00         2710      4500
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
# 3               2.0                   0                0
# 4               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# ...

# %%
df_data.describe()
# Out:
#                  id          Date      bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000  14620.000000         14620.000000
# mean   6.762821e+09  42604.538646      3.379343             2.129583
# std    6.237575e+03     67.347991      0.938719             0.769934
# min    6.762810e+09  42491.000000      1.000000             0.500000
# 25%    6.762815e+09  42546.000000      3.000000             1.750000
# 50%    6.762821e+09  42600.000000      3.000000             2.250000
# 75%    6.762826e+09  42662.000000      4.000000             2.500000
# max    6.762832e+09  42734.000000     33.000000             8.000000
#
#         living_area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
train_data,test_data = train_test_split(df_data[['living_area','bedrooms','Price']], test_size = 0.2, random_state=0)

# %%
train_data.head()
# Out:
#        living_area  bedrooms   Price
# 2157          4150         4  969990
# 2464          1720         3  514000
# 10326         1980         3  207000
# 7025          2450         3  450000
# 6625          1000         2  488000

# %%
train_data
# Out:
#        living_area  bedrooms   Price
# 2157          4150         4  969990
# 2464          1720         3  514000
# 10326         1980         3  207000
# 7025          2450         3  450000
# 6625          1000         2  488000
# ...            ...       ...     ...
# 13123         2620         3  469000
# 3264          2260         2  649000
# 9845          1260         3  342000
# 10799         2344         5  355000
# 2732          2650         4  542525
#
# [11696 rows x 3 columns]

# %%
Xtrain = train_data[['living_area','bedrooms']]
Ytrain = train_data[['Price']]

Xtest = test_data[['living_area','bedrooms']]
Ytest = test_data[['Price']]

# %% [markdown]
# ## Feature scaling

# %%
mean = Xtrain.mean()
std= Xtrain.std()

# %%
print(mean,std)
# Out:
# living_area    2101.163560
# bedrooms          3.378078
# dtype: float64 living_area    933.210237
# bedrooms         0.948352
# dtype: float64

# %%
Xtrain= (Xtrain - mean)/std

# %%
Xtrain
# Out:
#        living_area  bedrooms
# 2157      2.195471  0.655793
# 2464     -0.408443 -0.398669
# 10326    -0.129835 -0.398669
# 7025      0.373803 -0.398669
# 6625     -1.179974 -1.453130
# ...            ...       ...
# 13123     0.555970 -0.398669
# 3264      0.170204 -1.453130
# 9845     -0.901366 -0.398669
# 10799     0.260216  1.710254
# 2732      0.588117  0.655793
#
# [11696 rows x 2 columns]

# %%
Xtest = (Xtest - mean)/std

# %%
Xtest
# Out:
#        living_area  bedrooms
# 5670     -0.708483 -0.398669
# 12050     2.324060  0.655793
# 3916     -1.169258 -2.507591
# 2946     -0.140551 -0.398669
# 4597      0.234499 -0.398669
# ...            ...       ...
# 13029     3.084874  0.655793
# 4813      0.277361  1.710254
# 1556      0.138057  0.655793
# 8083      0.652411 -0.398669
# 1665     -0.922797 -0.398669
#
# [2924 rows x 2 columns]

# %%
fig = plt.figure(figsize=(16,10))
ax= fig.add_subplot(111,projection='3d')
ax.scatter(Xtrain['living_area'],Xtrain['bedrooms'],Ytrain,c='blue',marker='o',alpha=0.4)
ax.set_xlabel('Living_area')
ax.set_ylabel('Bedrooms')
ax.set_zlabel('Price')
plt.show()

# %%
Xtrain = np.array(Xtrain)
Ytrain= np.array(Ytrain)

# %%
print('Xtrain', Xtrain.shape, 'Ytrain',Ytrain.shape)
print('Xtrain', Xtest.shape, 'Ytrain',Ytest.shape)
# Out:
# Xtrain (11696, 2) Ytrain (11696, 1)
# Xtrain (2924, 2) Ytrain (2924, 1)

# %%
Xtrain = np.c_[np.ones(Xtrain.shape[0]),Xtrain]
Xtest = np.c_[np.ones(Xtest.shape[0]),Xtest]

# %%
print('Xtrain', Xtrain.shape, 'Ytrain',Ytrain.shape)
print('Xtrain', Xtest.shape, 'Ytrain',Ytest.shape)
# Out:
# Xtrain (11696, 3) Ytrain (11696, 1)
# Xtrain (2924, 3) Ytrain (2924, 1)

# %%
Xtrain
# Out:
# array([[ 1.        ,  2.19547146,  0.65579272],
#        [ 1.        , -0.4084434 , -0.3986686 ],
#        [ 1.        , -0.12983522, -0.3986686 ],
#        ...,
#        [ 1.        , -0.90136555, -0.3986686 ],
#        [ 1.        ,  0.26021622,  1.71025405],
#        [ 1.        ,  0.58811661,  0.65579272]])

# %% [markdown]
# ## Hypothesis

# %%
def hypothesis(X,theta):
#     print(theta)
    hyp = np.dot(X,theta)
    return hyp

# %% [markdown]
# ## Cost/Error function

# %%
def cost(X,Y,theta):
#     print(theta)
    N = Y.size
    cost = 0.0
    hyp = hypothesis(X,theta)
    cost = (1/(2*float(N)))*np.sum(np.square(Y-hyp))
    return cost

# %% [markdown]
# ## Gradient Decent algo

# %%
def GradientDescent(X,Y,theta,alpha=0.01,num_iters = 200):
    N = Y.size
    history = np.zeros(num_iters)
    for i in np.arange(num_iters):
        h = hypothesis(X,theta)
        theta = theta - alpha*((-1/float(N)) * (X.T.dot(Y-h)))
        history[i] = cost(X,Y,theta)
    return (theta,history)

# %%
theta = np.expand_dims(np.random.randn(3),axis=1)

# %%
theta.shape
# Out:
# (3, 1)

# %%
theta
# Out:
# array([[ 1.61363422],
#        [ 0.40489377],
#        [-1.83121847]])

# %%
cost(Xtrain,Ytrain,theta)
# Out:
# 212678564864.1168

# %%
theta, Cost_E = GradientDescent(Xtrain,Ytrain,theta)
print('theta:',theta.ravel())

plt.plot(Cost_E)
plt.ylabel('Cost/error')
plt.xlabel('Iterations')
# Out:
# theta: [467348.28990746 213750.82315658  15400.14831178]
# Text(0.5, 0, 'Iterations')

# %% [markdown]
# ## Visualization

# %%
x_surf, y_surf = np.meshgrid(np.linspace(Xtrain[:,1].min(),Xtrain[:,1].max(),100),np.linspace(Xtrain[:,2].min(),Xtrain[:,2].max(),100),)
X = pd.DataFrame({'Living_area':x_surf.ravel(), 'Bedrooms':y_surf.ravel()})
Z = theta[0,0] + (theta[1,0]*x_surf.ravel()) + (theta[2,0]*y_surf.ravel())
Z = np. reshape(Z, (100, 100))

# %%
fig = plt.figure(figsize=(16,15))
ax = fig.add_subplot(111,projection='3d')
ax.scatter(Xtrain[:,0],Xtrain[:,1],Ytrain,c='blue',marker='o',alpha=0.5)
ax.plot_surface(x_surf,y_surf,Z,rstride=1,cstride=1, cmap=cm.jet, alpha=0.5)
ax.set_xlabel('Living_area')
ax.set_ylabel('Bedrooms')
ax.set_zlabel('Price')
plt.show()
